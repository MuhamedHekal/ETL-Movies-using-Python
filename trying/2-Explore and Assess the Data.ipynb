# %%
import pandas as pd 
import os

# %%
os.listdir("./data/in/the-movies-dataset")
# Out:
# ['credits.csv',
#  'keywords.csv',
#  'links.csv',
#  'links_small.csv',
#  'movies_metadata.csv',
#  'ratings.csv',
#  'ratings_small.csv']

# %%
df = pd.read_csv('./data/in/the-movies-dataset/credits.csv')
md =pd.read_csv('./data/in/the-movies-dataset/movies_metadata.csv')
rating = pd.read_csv('./data/in/the-movies-dataset/ratings.csv')
# Out:
# C:\Users\hheka\AppData\Local\Temp\ipykernel_17080\255022332.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   md =pd.read_csv('./data/in/the-movies-dataset/movies_metadata.csv')

# %%
df = df.iloc[:10]
md = md.iloc[:10]
rating = rating.iloc[:10]

# %%
len(df.cast)
# Out:
# 10

# %%
cast = pd.DataFrame()
for i in range(len(df.cast)):
    test_str  = df.cast[i]
    res = list(eval(test_str))
    res = pd.DataFrame(res)
    res['movie_id'] = df['id'][i]
    cast = pd.concat([cast,res],axis=0,ignore_index= True)

# %%
cast.head()
# Out:
#    cast_id                character                 credit_id  gender     id  \
# 0       14            Woody (voice)  52fe4284c3a36847f8024f95       2     31
# 1       15   Buzz Lightyear (voice)  52fe4284c3a36847f8024f99       2  12898
# 2       16  Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d       2   7167
# 3       17       Slinky Dog (voice)  52fe4284c3a36847f8024fa1       2  12899
# 4       18              Rex (voice)  52fe4284c3a36847f8024fa5       2  12900
#
#             name  order                      profile_path  movie_id
# 0      Tom Hanks      0  /pQFoyx7rp09CJTAb932F2g8Nlho.jpg       862
# 1      Tim Allen      1  /uX2xVf6pMmPepxnvFWyBtjexzgY.jpg       862
# 2    Don Rickles      2  /h5BcaDMPRVLHLDzbQavec4xfSdt.jpg       862
# 3     Jim Varney      3  /eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg       862
# 4  Wallace Shawn      4  /oGE6JqPP2xH4tNORKNqxbNPYi7u.jpg       862

# %%
crew = pd.DataFrame()
for i in range(len(df.crew)):
    test_str  = df.crew[i]
    res = list(eval(test_str))
    res = pd.DataFrame(res)
    res['movie_id'] = df['id'][i]
    crew = pd.concat([crew,res],axis=0,ignore_index= True)

# %%
crew.head()
# Out:
#                   credit_id department  gender     id         job  \
# 0  52fe4284c3a36847f8024f49  Directing       2   7879    Director
# 1  52fe4284c3a36847f8024f4f    Writing       2  12891  Screenplay
# 2  52fe4284c3a36847f8024f55    Writing       2      7  Screenplay
# 3  52fe4284c3a36847f8024f5b    Writing       2  12892  Screenplay
# 4  52fe4284c3a36847f8024f61    Writing       0  12893  Screenplay
#
#              name                      profile_path  movie_id
# 0   John Lasseter  /7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg       862
# 1     Joss Whedon  /dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg       862
# 2  Andrew Stanton  /pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg       862
# 3      Joel Cohen  /dAubAiZcvKFbboWlj7oXOkZnTSu.jpg       862
# 4    Alec Sokolow  /v79vlRYi94BZUQnkkyznbGUZLjT.jpg       862

# %%
md.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
company_name = pd.DataFrame()
for i in range(len(md.production_companies)):
    test_str  = md.production_companies[i]
    res = list(eval(test_str))
    res = pd.DataFrame(res)
    res['movie_id'] = md['id'][i]
    company_name = pd.concat([company_name,res],axis=0,ignore_index= True)

# %%
company_name
# Out:
#                                       name     id movie_id
# 0                  Pixar Animation Studios      3      862
# 1                         TriStar Pictures    559     8844
# 2                             Teitler Film   2550     8844
# 3                Interscope Communications  10201     8844
# 4                             Warner Bros.   6194    15602
# 5                           Lancaster Gate  19464    15602
# 6   Twentieth Century Fox Film Corporation    306    31357
# 7                    Sandollar Productions   5842    11862
# 8                      Touchstone Pictures   9195    11862
# 9                      Regency Enterprises    508      949
# 10                            Forward Pass    675      949
# 11                            Warner Bros.   6194      949
# 12                      Paramount Pictures      4    11860
# 13                 Scott Rudin Productions    258    11860
# 14                      Mirage Enterprises    932    11860
# ...

# %%
md.production_companies[9]
# Out:
# "[{'name': 'United Artists', 'id': 60}, {'name': 'Eon Productions', 'id': 7576}]"

# %%
os.makedirs('test')
crew.to_csv("test/crew.csv", index=False)
cast.to_csv("test/cast.csv", index=False)
md.to_csv("test/md.csv", index=False)
gen.to_csv("test/gen.csv", index=False)

# %%
md.shape
# Out:
# (45466, 24)

# %%
md.production_companies[5]
# Out:
# "[{'name': 'Regency Enterprises', 'id': 508}, {'name': 'Forward Pass', 'id': 675}, {'name': 'Warner Bros.', 'id': 6194}]"

# %%
cast
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 cast
#
# NameError: name 'cast' is not defined
